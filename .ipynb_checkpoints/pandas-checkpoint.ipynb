# %%
# Rename column
import pandas as pd
# Limit the number data displayed
data = pd.read_csv("winemag.csv", index_col=0)
pd.set_option('display.max_rows', 5)
data
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# ...                               ...     ...    ...                ...
# 129969                            NaN      90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#        region_1 region_2    taster_name taster_twitter_handle  \
# ...

# %%
# shape attribute to check how large the resulting DataFrame
data.shape
# Out:
# (129971, 13)

# %%
# Examine the contents of the resultant DataFrame using the head() command
data.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %%
# Selecting Columns type 1
data.province.head()
# Out:
# 0    Sicily & Sardinia
# 1                Douro
# 2               Oregon
# 3             Michigan
# 4               Oregon
# Name: province, dtype: object

# %%
# Selecting Columns type 2
data['province'].head()
# Out:
# 0    Sicily & Sardinia
# 1                Douro
# 2               Oregon
# 3             Michigan
# 4               Oregon
# Name: province, dtype: object

# %%
# Selecting specific value using index
data['province'][1]
# select the second row
# Out:
# 'Douro'

# %%
# Select specific row using iloc, index-based
a = data.iloc[0]
a.province
# Out:
# 'Sicily & Sardinia'

# %%
# get a column with iloc
data.iloc[-5:,1]
# this code to select the second column, start from 0 for the first column and
# Out:
# 129966    Notes of honeysuckle and cantaloupe sweeten th...
# 129967    Citation is given as much as a decade of bottl...
# 129968    Well-drained gravel soil gives this wine its c...
# 129969    A dry style of Pinot Gris, this is crisp with ...
# 129970    Big, rich and off-dry, this is powered by inte...
# Name: description, dtype: object

# %%
data.loc[:2,'province']
# this command is meant to select the data from index 0 to 2 (rows) and column province
# Out:
# 0    Sicily & Sardinia
# 1                Douro
# 2               Oregon
# Name: province, dtype: object

# %%
# get the first three row in the first column
data.iloc[:3,0]
# Out:
# 0       Italy
# 1    Portugal
# 2          US
# Name: country, dtype: object

# %%
#  select just the second and third entries
data.iloc[1:3,0]
# Out:
# 1    Portugal
# 2          US
# Name: country, dtype: object

# %%
# possible to pass a list 
data.iloc[[2,4,5],0]
# Out:
# 2       US
# 4       US
# 5    Spain
# Name: country, dtype: object

# %%
# the last five elements of the dataset, and column with index 2 and 3
data.iloc[-5:,[2,3]]
# Out:
#                                    designation  points
# 129966  Brauneberger Juffer-Sonnenuhr Spätlese      90
# 129967                                     NaN      90
# 129968                                   Kritt      90
# 129969                                     NaN      90
# 129970           Lieu-dit Harth Cuvée Caroline      90

# %%
data.iloc[:5]
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %%
# label-based selection
data.loc[2,'province']
# SQL be like : select province from data where index='2'
# Out:
# 'Oregon'

# %%
# Conditional Selection
data.country[5] == 'Italy'
# Out:
# False

# %%
data.loc[data.country == 'Portugal']
# POV SQL -> select * from data where country = 'Portugal'
# Out:
#          country                                        description  \
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 79      Portugal  Grown on the sandy soil of Tejo, the wine is t...
# ...          ...                                                ...
# 129901  Portugal  Wood fermentation and aging have given this fi...
# 129960  Portugal  Fresh and fruity, this is full of red cherry f...
#
#        designation  points  price         province region_1 region_2  \
# 1         Avidagos      87   15.0            Douro      NaN      NaN
# 79          Bridão      86    NaN             Tejo      NaN      NaN
# ...            ...     ...    ...              ...      ...      ...
# 129901         NaN      91   30.0  Beira Atlantico      NaN      NaN
# 129960     Vértice      90   48.0            Douro      NaN      NaN
#
#        taster_name taster_twitter_handle  \
# 1       Roger Voss            @vossroger
# 79      Roger Voss            @vossroger
# ...

# %%
data.loc[(data.country=='Portugal')&(data.points>90)]
# POV SQL -> select * from data where country='Portugal' and points>90
# Out:
#          country                                        description  \
# 151     Portugal  This bottling shows a rich, wood-aged wine, fu...
# 157     Portugal  From an estate in the south of the Alentejo, t...
# ...          ...                                                ...
# 129685  Portugal  The red-juice grape Alicante Bouschet gives a ...
# 129901  Portugal  Wood fermentation and aging have given this fi...
#
#                                   designation  points  price  \
# 151     Gerações Colheita Seleccionada Branco      91   30.0
# 157                      Grande Reserva Tinto      91   26.0
# ...                                       ...     ...    ...
# 129685                               Comporta      93   50.0
# 129901                                    NaN      91   30.0
#
#                     province region_1 region_2 taster_name  \
# 151               Alentejano      NaN      NaN  Roger Voss
# 157               Alentejano      NaN      NaN  Roger Voss
# ...

# %%
data.loc[(data.country=='Portugal')|(data.points>92)]
# POV SQL -> select * from data where country='Portugal' or points>90
# Out:
#          country                                        description  \
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 79      Portugal  Grown on the sandy soil of Tejo, the wine is t...
# ...          ...                                                ...
# 129901  Portugal  Wood fermentation and aging have given this fi...
# 129960  Portugal  Fresh and fruity, this is full of red cherry f...
#
#        designation  points  price         province region_1 region_2  \
# 1         Avidagos      87   15.0            Douro      NaN      NaN
# 79          Bridão      86    NaN             Tejo      NaN      NaN
# ...            ...     ...    ...              ...      ...      ...
# 129901         NaN      91   30.0  Beira Atlantico      NaN      NaN
# 129960     Vértice      90   48.0            Douro      NaN      NaN
#
#        taster_name taster_twitter_handle  \
# 1       Roger Voss            @vossroger
# 79      Roger Voss            @vossroger
# ...

# %%
data.loc[data.country.isin(['Italy','France'])]
# POV SQL -> select * from data where country in ('Italy','France')
# Out:
#        country                                        description  \
# 0        Italy  Aromas include tropical fruit, broom, brimston...
# 6        Italy  Here's a bright, informal red that opens with ...
# ...        ...                                                ...
# 129969  France  A dry style of Pinot Gris, this is crisp with ...
# 129970  France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 6                             Belsito      87   16.0  Sicily & Sardinia
# ...                               ...     ...    ...                ...
# 129969                            NaN      90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#         region_1 region_2    taster_name taster_twitter_handle  \
# 0           Etna      NaN  Kerin O’Keefe          @kerinokeefe
# ...

# %%
data.loc[data.price.notnull()]
# POV SQL -> select * from data where price is not null
# Out:
#          country                                        description  \
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price province  \
# 1                            Avidagos      87   15.0    Douro
# 2                                 NaN      87   14.0   Oregon
# ...                               ...     ...    ...      ...
# 129969                            NaN      90   32.0   Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0   Alsace
#
#                  region_1           region_2   taster_name  \
# 1                     NaN                NaN    Roger Voss
# 2       Willamette Valley  Willamette Valley  Paul Gregutt
# ...

# %%
data.columns
# Out:
# Index(['country', 'description', 'designation', 'points', 'price', 'province',
#        'region_1', 'region_2', 'taster_name', 'taster_twitter_handle', 'title',
#        'variety', 'winery'],
#       dtype='object')

# %%
# assign a new column with any certain value
data['versi'] = 1
data.columns
# Out:
# Index(['country', 'description', 'designation', 'points', 'price', 'province',
#        'region_1', 'region_2', 'taster_name', 'taster_twitter_handle', 'title',
#        'variety', 'winery', 'versi'],
#       dtype='object')

# %%
# Create dataframe from dictionary
x = {'Name':['boni','bona','banu'],'Age':[5,8,9]}
y = pd.DataFrame(x,index=[1,2,3])
y
# Out:
#    Name  Age
# 1  boni    5
# 2  bona    8
# 3  banu    9

# %%
data.rename(columns={'points': 'score'})
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  score  price           province  \
# 0                        Vulkà Bianco     87    NaN  Sicily & Sardinia
# 1                            Avidagos     87   15.0              Douro
# ...                               ...    ...    ...                ...
# 129969                            NaN     90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline     90   21.0             Alsace
#
#        region_1 region_2    taster_name taster_twitter_handle  \
# 0          Etna      NaN  Kerin O’Keefe          @kerinokeefe
# ...
